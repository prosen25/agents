# %%
from dotenv import load_dotenv
from agents import Agent, Runner, trace

# %%
load_dotenv(override=True)
# Out:
# True

# %%
agent = Agent(name="Jokester", instructions="You are a joke teller", model="gpt-4o-mini")

# %%
with trace(workflow_name="Telling a joke"):
    result = await Runner.run(starting_agent=agent, input="Tell me a joke about Agentic AI")
    print(result.final_output)
# Out:
# Why did the Agentic AI bring a ladder to the bar?
#
# Because it heard the drinks were on the house!
